# %% [markdown]
# # 1D-CNN OPTUNA STUDY
# (In order to set beta & learning rate & alpha according to ROC_AUC value)

# %%
from torch import nn
import torch
import torch.optim as optim
from tqdm import *
import matplotlib.pyplot as plt
from kornia.losses import focal # pip3 install kornia will be required
import numpy as np
from sklearn import metrics
from pathlib import Path
import pandas as pd
import nibabel as nib
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from tqdm.notebook import tqdm
import warnings
warnings.filterwarnings("ignore")
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
import optuna # requires pip3 install optuna
import joblib

# %% [markdown]
# #### Define the Optuna objective

# %%
from OptunaObjective_ROI import objective # already defined in python file

# %% [markdown]
# #### Carry out optuna study

# %%
sampler = optuna.samplers.TPESampler()
study = optuna.create_study(sampler=sampler, direction='maximize')
study.optimize(objective, n_trials=400)#100)
joblib.dump(study, 'optuna_results.pkl')
print(study.best_trial)
print("\n \n \n --- BEST PARAMETERS ---")
for param in study.best_params:
    print(param, study.best_params[param])
# Out:
# [I 2022-08-05 00:01:58,889] A new study created in memory with name: no-name-7f72b8bf-17f1-420e-80e1-e352e386fc10
# [I 2022-08-05 00:04:35,211] Trial 0 finished with value: 0.5 and parameters: {'lr': 0.0018654846085689404, 'gamma': 14.062494248252436, 'alpha': 0.3425314034668169}. Best is trial 0 with value: 0.5.
# [I 2022-08-05 00:07:09,627] Trial 1 finished with value: 0.5 and parameters: {'lr': 0.027603669569827183, 'gamma': 15.622203329851278, 'alpha': 0.6539476071321676}. Best is trial 0 with value: 0.5.
# [I 2022-08-05 00:09:55,169] Trial 2 finished with value: 0.5038431202047934 and parameters: {'lr': 0.00043503447419277657, 'gamma': 34.91748632985666, 'alpha': 0.8923805233276448}. Best is trial 2 with value: 0.5038431202047934.
# [I 2022-08-05 00:12:55,794] Trial 3 finished with value: 0.5001602266037365 and parameters: {'lr': 0.001370619919756917, 'gamma': 33.992273093617115, 'alpha': 0.6868806618317667}. Best is trial 2 with value: 0.5038431202047934.
# ...
