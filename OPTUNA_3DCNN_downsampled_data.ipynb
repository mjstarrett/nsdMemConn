# %% [markdown]
# # 3D-CNN OPTUNA STUDY
# (In order to set beta & learning rate according to ROC_AUC value)

# %%
from torch import nn
import torch
import torch.optim as optim
from tqdm import *
import matplotlib.pyplot as plt
from kornia.losses import focal # pip3 install kornia will be required
import numpy as np
from sklearn import metrics
from pathlib import Path
import pandas as pd
import nibabel as nib
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from tqdm.notebook import tqdm
import warnings
warnings.filterwarnings("ignore")
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
import optuna # requires pip3 install optuna
import joblib

# %% [markdown]
# #### Define the Optuna objective

# %%
from OptunaObjective_downsampled_data import objective # already defined in python file

# %% [markdown]
# #### Carry out optuna study

# %%
sampler = optuna.samplers.TPESampler()
study = optuna.create_study(sampler=sampler, direction='maximize')
study.optimize(objective, n_trials=500)#100)
joblib.dump(study, 'optuna_results.pkl')
print(study.best_trial)
print("\n \n \n --- BEST PARAMETERS ---")
for param in study.best_params:
    print(param, study.best_params[param])
# Out:
# [I 2022-08-04 12:37:26,797] A new study created in memory with name: no-name-164b6ea6-8245-46b3-8a28-26ef2ea6ba71
# [I 2022-08-04 12:37:41,156] Trial 0 finished with value: 0.5027574342759612 and parameters: {'lr': 0.0003934623342849457, 'gamma': 36.328574148365206}. Best is trial 0 with value: 0.5027574342759612.
# [I 2022-08-04 12:37:55,065] Trial 1 finished with value: 0.5 and parameters: {'lr': 0.04815421097374864, 'gamma': 33.51203796942509}. Best is trial 0 with value: 0.5027574342759612.
# [I 2022-08-04 12:38:13,742] Trial 2 finished with value: 0.49992853058890796 and parameters: {'lr': 0.00036524085941208346, 'gamma': 14.331690203364841}. Best is trial 0 with value: 0.5027574342759612.
# [I 2022-08-04 12:38:32,770] Trial 3 finished with value: 0.4998570611778159 and parameters: {'lr': 0.0013945078711713344, 'gamma': 6.588415150374118}. Best is trial 0 with value: 0.5027574342759612.
# ...
